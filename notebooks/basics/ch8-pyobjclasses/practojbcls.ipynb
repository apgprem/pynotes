# %%
class parent:
    pass

p = parent()
print(p)

# %%
class Person:
    pass

p1 = Person()
print(p1)

# %%
class person:
    name="Alice"
    age=35

p = person()
print(p.name)
print(p.age)
# Out:
# Alice
# 35
