# %%
fruits = ["apple", "banana", "orange","5",5, 7.6]

for fruit in fruits:
    print(fruit)
# Out:
# apple
# banana
# orange
# 5
# 5
# 7.6

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
