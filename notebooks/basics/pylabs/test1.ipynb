# %%
for i in range(3):
    for j in range(2):
        print(f"i={i}, j={j}")
# Out:
# i=0, j=0
# i=0, j=1
# i=1, j=0
# i=1, j=1
# i=2, j=0
# i=2, j=1

# %%
rows = 5
for i in range(1, rows + 1):
    print("* ", i)
# Out:
# *  1
# *  2
# *  3
# *  4
# *  5

# %%
rows = 5
for i in range(rows, 0 , -1):
    print("* ", i)
# Out:
# *  5
# *  4
# *  3
# *  2
# *  1
