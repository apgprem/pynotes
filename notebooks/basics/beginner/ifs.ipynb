# %%
age = -18

if age >= 18:
    print("Eligible to vote")

# %%
temperature = 26

if temperature > 25:
    print("It's warm outside")
else:
    print("It's cold outside")
# Out:
# It's warm outside

# %%
score = 55

if score >= 90:
    print("Grade: A")
elif score >= 75:
    print("Grade: B")
elif score >= 60:
    print("Grade: C")
else:
    print("Grade: D")
# Out:
# Grade: D

# %%
username = "admin"
password = "1234"

if username == "admin":
    if password == "1234":
        print("Access granted")
    else:
        print("Incorrect password")
# Out:
# Access granted

# %%
age = 25
is_verified = True

if age > 18 and is_verified:
    print("User can proceed")
# Out:
# User can proceed

# %%
x = 10

if x > 5: print("x is greater than 5")
# Out:
# x is greater than 5

# %%
num = 20

result = "Even" if num % 2 == 0 else "Odd"
print(result)  # Output: Odd
# Out:
# Even

# %%
day = "Sunday"

if day in ["Saturday", "Sunday"]:
    print("Weekend")
else:
    print("Weekday")
# Out:
# Weekend

# %%
username = 'alice'

if username.lower() == "alice":
    print("Welcome Alice")
# Out:
# Welcome Alice

# %%
value = 6

if value > 0:
    pass  # Placeholder for future logic
    print("Program continues1111...")

print("Program continues...")
# Out:
# Program continues1111...
# Program continues...
